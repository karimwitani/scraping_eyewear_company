# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %%
print(datetime.now())
# Out:
# 2021-09-10 12:22:05.852680

# %%
sections_dict = catalogue_sections_getter()
print(sections_dict)
# Out:
# {'Sunglasses': 'https://eyewa.com/ae-en/sunglasses.html', 'Glasses': 'https://eyewa.com/ae-en/glasses.html', 'Blue Light Glasses': 'https://eyewa.com/ae-en/blue-light-glasses.html', 'Corrective Contact Lenses': 'https://eyewa.com/ae-en/corrective-contact-lenses.html', 'Color Contact Lenses': 'https://eyewa.com/ae-en/color-contact-lenses.html', 'Clearance': 'https://eyewa.com/ae-en/clearance-sale.html'}

# %%
all_products_dict = product_list_getter(sections_dict)
# Out:
# getting data from https://eyewa.com/ae-en/sunglasses.html
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=5
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=6
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=7
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=8
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=9
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=10
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=11
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=12
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=13
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=14
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=15
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=16
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=17
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=18
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=19
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=20
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=21
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=22
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=23
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=24
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=25
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=26
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=27
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=28
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=29
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=30
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=31
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=32
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=33
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=34
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=35
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=36
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=37
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=38
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=39
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=40
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=41
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=42
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=43
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=44
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=45
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=46
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=47
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=48
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=49
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=50
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=51
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=52
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=53
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=54
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=55
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=56
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=57
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=58
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=59
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=60
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=61
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=62
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=63
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=64
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=65
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=66
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=67
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=68
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=69
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=70
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=71
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=72
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=73
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=74
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=75
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=76
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=77
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=78
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=79
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=80
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=81
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=82
# 'NoneType' object has no attribute 'find_all'
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=83
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=84
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=85
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=86
# getting data from https://eyewa.com/ae-en/sunglasses.html?html_parser=&p=87
# End of the ride for this category
# getting data from https://eyewa.com/ae-en/glasses.html
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=5
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=6
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=7
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=8
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=9
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=10
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=11
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=12
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=13
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=14
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=15
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=16
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=17
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=18
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=19
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=20
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=21
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=22
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=23
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=24
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=25
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=26
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=27
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=28
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=29
# getting data from https://eyewa.com/ae-en/glasses.html?html_parser=&p=30
# End of the ride for this category
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=5
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=6
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=7
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=8
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=9
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=10
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=11
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=12
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=13
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=14
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=15
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=16
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=17
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=18
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=19
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=20
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=21
# getting data from https://eyewa.com/ae-en/blue-light-glasses.html?html_parser=&p=22
# End of the ride for this category
# getting data from https://eyewa.com/ae-en/corrective-contact-lenses.html
# getting data from https://eyewa.com/ae-en/corrective-contact-lenses.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/corrective-contact-lenses.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/corrective-contact-lenses.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/corrective-contact-lenses.html?html_parser=&p=5
# End of the ride for this category
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=5
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=6
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=7
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=8
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=9
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=10
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=11
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=12
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=13
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=14
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=15
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=16
# getting data from https://eyewa.com/ae-en/color-contact-lenses.html?html_parser=&p=17
# End of the ride for this category
# getting data from https://eyewa.com/ae-en/clearance-sale.html
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=2
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=3
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=4
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=5
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=6
# getting data from https://eyewa.com/ae-en/clearance-sale.html?html_parser=&p=7
# End of the ride for this category

# %%
all_products_dict2 = product_detail_getter_2(all_products_dict)
# Out:
# getting data from https://eyewa.com/ae-en/blackout-midnight-000215-0707.html
# html response for BlackOut MIDNIGHT: 200
# found productPriceInfo tag for BlackOut MIDNIGHT
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69406" data-product-id="69406" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="199" data-price-type="finalPrice" id="product-price-69406">
# <span class="price">AED 199</span> </span>
# </span>
# </div></div>
# Getting product attributes for BlackOut MIDNIGHT
# getting data from https://eyewa.com/ae-en/blackout-serene-000107-0107.html
# html response for BlackOut SERENE: 200
# found productPriceInfo tag for BlackOut SERENE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59934" data-product-id="59934" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="199" data-price-type="finalPrice" id="product-price-59934">
# <span class="price">AED 199</span> </span>
# </span>
# </div></div>
# Getting product attributes for BlackOut SERENE
# getting data from https://eyewa.com/ae-en/blackout-coachella-000206-2707.html
# html response for BlackOut COACHELLA: 200
# found productPriceInfo tag for BlackOut COACHELLA
# Getting product attributes for BlackOut COACHELLA
# getting data from https://eyewa.com/ae-en/30sundays-smooth-sailing-000210-2706.html
# html response for 30Sundays SMOOTH SAILING: 200
# found productPriceInfo tag for 30Sundays SMOOTH SAILING
# Getting product attributes for 30Sundays SMOOTH SAILING
# getting data from https://eyewa.com/ae-en/blackout-moonlight-000214-2706.html
# html response for BlackOut MOONLIGHT: 200
# found productPriceInfo tag for BlackOut MOONLIGHT
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69404" data-product-id="69404" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="199" data-price-type="finalPrice" id="product-price-69404">
# <span class="price">AED 199</span> </span>
# </span>
# </div></div>
# Getting product attributes for BlackOut MOONLIGHT
# getting data from https://eyewa.com/ae-en/roav-jett-8202-12-41.html
# html response for ROAV Jett: 200
# found productPriceInfo tag for ROAV Jett
# Getting product attributes for ROAV Jett
# getting data from https://eyewa.com/ae-en/marc-jacobs-20387580754ha-black.html
# html response for MARC JACOBS - MARC 551/G/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 551/G/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69974" data-product-id="69974" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="559" data-price-type="finalPrice" id="product-price-69974">
# <span class="price">AED 559</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 551/G/S
# getting data from https://eyewa.com/ae-en/30sundays-en-vogue-000108-0907.html
# html response for 30Sundays EN VOGUE: 200
# found productPriceInfo tag for 30Sundays EN VOGUE
# Getting product attributes for 30Sundays EN VOGUE
# getting data from https://eyewa.com/ae-en/30sundays-all-aboard-000212-2706.html
# html response for 30Sundays ALL ABOARD: 200
# found productPriceInfo tag for 30Sundays ALL ABOARD
# Getting product attributes for 30Sundays ALL ABOARD
# getting data from https://eyewa.com/ae-en/30sundays-maverick-000203-1207.html
# html response for 30Sundays MAVERICK: 200
# found productPriceInfo tag for 30Sundays MAVERICK
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59154" data-product-id="59154" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="369" data-price-type="finalPrice" id="product-price-59154">
# <span class="price">AED 369</span> </span>
# </span>
# </div></div>
# Getting product attributes for 30Sundays MAVERICK
# getting data from https://eyewa.com/ae-en/30sundays-thats-hot-000127-1306.html
# html response for 30Sundays THAT'S HOT: 200
# found productPriceInfo tag for 30Sundays THAT'S HOT
# Getting product attributes for 30Sundays THAT'S HOT
# getting data from https://eyewa.com/ae-en/30sundays-maestro-000221-0107.html
# html response for 30Sundays MAESTRO: 200
# found productPriceInfo tag for 30Sundays MAESTRO
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59035" data-product-id="59035" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-59035">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for 30Sundays MAESTRO
# getting data from https://eyewa.com/ae-en/blackout-kalinda-000210-1302.html
# html response for BlackOut KALINDA: 200
# found productPriceInfo tag for BlackOut KALINDA
# Getting product attributes for BlackOut KALINDA
# getting data from https://eyewa.com/ae-en/roav-maverick-8207-13-14.html
# html response for ROAV Maverick: 200
# found productPriceInfo tag for ROAV Maverick
# Getting product attributes for ROAV Maverick
# getting data from https://eyewa.com/ae-en/30sundays-challenger-000211-1304.html
# html response for 30Sundays CHALLENGER: 200
# found productPriceInfo tag for 30Sundays CHALLENGER
# Getting product attributes for 30Sundays CHALLENGER
# getting data from https://eyewa.com/ae-en/30sundays-olympian-000219-0107.html
# html response for 30Sundays OLYMPIAN: 200
# found productPriceInfo tag for 30Sundays OLYMPIAN
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59029" data-product-id="59029" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-59029">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for 30Sundays OLYMPIAN
# getting data from https://eyewa.com/ae-en/30sundays-voyager-000216-1306.html
# html response for 30Sundays VOYAGER: 200
# found productPriceInfo tag for 30Sundays VOYAGER
# Getting product attributes for 30Sundays VOYAGER
# getting data from https://eyewa.com/ae-en/marc-jacobs-202581kb7609o-gray.html
# html response for MARC JACOBS - MARC 406/G/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 406/G/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69953" data-product-id="69953" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="719" data-price-type="finalPrice" id="product-price-69953">
# <span class="price">AED 719</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 406/G/S
# getting data from https://eyewa.com/ae-en/roav-virgil-8003-11-11.html
# html response for ROAV Virgil: 200
# found productPriceInfo tag for ROAV Virgil
# Getting product attributes for ROAV Virgil
# getting data from https://eyewa.com/ae-en/30sundays-globe-trotter-000218-1306.html
# html response for 30Sundays GLOBE TROTTER: 200
# found productPriceInfo tag for 30Sundays GLOBE TROTTER
# Getting product attributes for 30Sundays GLOBE TROTTER
# getting data from https://eyewa.com/ae-en/roav-earhart-1001-13-41.html
# html response for ROAV Earhart: 200
# found productPriceInfo tag for ROAV Earhart
# Getting product attributes for ROAV Earhart
# getting data from https://eyewa.com/ae-en/polaroid-203938ahy47m9-beige.html
# html response for Polaroid - Junior PLD 8041/S: 200
# found productPriceInfo tag for Polaroid - Junior PLD 8041/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70048" data-product-id="70048" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="179" data-price-type="finalPrice" id="product-price-70048">
# <span class="price">AED 179</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - Junior PLD 8041/S
# getting data from https://eyewa.com/ae-en/polaroid-233713cyq45ai-pink.html
# html response for Polaroid - Junior PLD 8019/S: 200
# found productPriceInfo tag for Polaroid - Junior PLD 8019/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70036" data-product-id="70036" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="269" data-price-type="finalPrice" id="product-price-70036">
# <span class="price">AED 269</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - Junior PLD 8019/S
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29011218-white.html
# html response for Mr. Wonderful White Cat Eye - MW29011218: 200
# found productPriceInfo tag for Mr. Wonderful White Cat Eye - MW29011218
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69917" data-product-id="69917" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="309" data-price-type="finalPrice" id="product-price-69917">
# <span class="price">AED 309</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful White Cat Eye - MW29011218
# getting data from https://eyewa.com/ae-en/30sundays-round-up-000204-0207.html
# html response for 30Sundays ROUND UP: 200
# found productPriceInfo tag for 30Sundays ROUND UP
# Getting product attributes for 30Sundays ROUND UP
# getting data from https://eyewa.com/ae-en/30sundays-sharpshooter-000222-0207.html
# html response for 30Sundays SHARPSHOOTER: 200
# found productPriceInfo tag for 30Sundays SHARPSHOOTER
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59039" data-product-id="59039" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-59039">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for 30Sundays SHARPSHOOTER
# getting data from https://eyewa.com/ae-en/30sundays-pioneer-000214-1306.html
# html response for 30Sundays PIONEER: 200
# found productPriceInfo tag for 30Sundays PIONEER
# Getting product attributes for 30Sundays PIONEER
# getting data from https://eyewa.com/ae-en/polaroid-2034326lb62uc-silver.html
# html response for Polaroid - PLD 2105/G/S: 502
# <span class="cf-error-type">Error</span>
# retrying a new connection to https://eyewa.com/ae-en/polaroid-2034326lb62uc-silver.html
# found productPriceInfo tag for Polaroid - PLD 2105/G/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68617" data-product-id="68617" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-68617">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - PLD 2105/G/S
# getting data from https://eyewa.com/ae-en/polaroid-202933kj154uc-gray.html
# html response for Polaroid - PLD 2093/G/S: 200
# found productPriceInfo tag for Polaroid - PLD 2093/G/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68602" data-product-id="68602" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="249" data-price-type="finalPrice" id="product-price-68602">
# <span class="price">AED 249</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - PLD 2093/G/S
# getting data from https://eyewa.com/ae-en/blackout-liberty-000208-1302.html
# html response for BlackOut LIBERTY: 200
# found productPriceInfo tag for BlackOut LIBERTY
# Getting product attributes for BlackOut LIBERTY
# getting data from https://eyewa.com/ae-en/mvmt-street-goggle-stg-001.html
# html response for MVMT STREET GOGGLE: 200
# found productPriceInfo tag for MVMT STREET GOGGLE
# Getting product attributes for MVMT STREET GOGGLE
# getting data from https://eyewa.com/ae-en/30sundays-squared-away-000205-0404.html
# html response for 30Sundays SQUARED AWAY: 200
# found productPriceInfo tag for 30Sundays SQUARED AWAY
# Getting product attributes for 30Sundays SQUARED AWAY
# getting data from https://eyewa.com/ae-en/30sundays-thats-wow-000123-1304.html
# html response for 30Sundays THAT'S WOW: 200
# found productPriceInfo tag for 30Sundays THAT'S WOW
# Getting product attributes for 30Sundays THAT'S WOW
# getting data from https://eyewa.com/ae-en/30sundays-thats-rad-000130-2507.html
# html response for 30Sundays THAT'S RAD: 200
# found productPriceInfo tag for 30Sundays THAT'S RAD
# Getting product attributes for 30Sundays THAT'S RAD
# getting data from https://eyewa.com/ae-en/30sundays-navigator-000217-0107.html
# html response for 30Sundays NAVIGATOR: 200
# found productPriceInfo tag for 30Sundays NAVIGATOR
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59023" data-product-id="59023" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="369" data-price-type="finalPrice" id="product-price-59023">
# <span class="price">AED 369</span> </span>
# </span>
# </div></div>
# Getting product attributes for 30Sundays NAVIGATOR
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-jeans-20335200350ir-black.html
# html response for TOMMY HILFIGER Jeans - TJ 0030/S: 200
# found productPriceInfo tag for TOMMY HILFIGER Jeans - TJ 0030/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70008" data-product-id="70008" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="509" data-price-type="finalPrice" id="product-price-70008">
# <span class="price">AED 509</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER Jeans - TJ 0030/S
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-jeans-20305380760ir-black.html
# html response for TOMMY HILFIGER Jeans - TJ 0006/S: 200
# found productPriceInfo tag for TOMMY HILFIGER Jeans - TJ 0006/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70001" data-product-id="70001" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="509" data-price-type="finalPrice" id="product-price-70001">
# <span class="price">AED 509</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER Jeans - TJ 0006/S
# getting data from https://eyewa.com/ae-en/blackout-oceana-000212-0502.html
# html response for BlackOut OCEANA: 200
# found productPriceInfo tag for BlackOut OCEANA
# Getting product attributes for BlackOut OCEANA
# getting data from https://eyewa.com/ae-en/polaroid-202899ddb490f-gold.html
# html response for Polaroid Junior - PLD 8039/S - Age 9-16 Years: 200
# found productPriceInfo tag for Polaroid Junior - PLD 8039/S - Age 9-16 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68732" data-product-id="68732" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="179" data-price-type="finalPrice" id="product-price-68732">
# <span class="price">AED 179</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid Junior - PLD 8039/S - Age 9-16 Years
# getting data from https://eyewa.com/ae-en/blackout-mabel-000207-0804.html
# html response for BlackOut MABEL: 200
# found productPriceInfo tag for BlackOut MABEL
# Getting product attributes for BlackOut MABEL
# getting data from https://eyewa.com/ae-en/mvmt-classic-round-clr-002.html
# html response for MVMT CLASSIC ROUND: 200
# found productPriceInfo tag for MVMT CLASSIC ROUND
# Getting product attributes for MVMT CLASSIC ROUND
# getting data from https://eyewa.com/ae-en/artlife-balzac-al30059201.html
# html response for Artlife BALZAC: 200
# found productPriceInfo tag for Artlife BALZAC
# Getting product attributes for Artlife BALZAC
# getting data from https://eyewa.com/ae-en/artlife-jones-al30040100.html
# html response for Artlife JONES: 200
# found productPriceInfo tag for Artlife JONES
# Getting product attributes for Artlife JONES
# getting data from https://eyewa.com/ae-en/roav-dixon-8006-12-14.html
# html response for ROAV Dixon: 200
# found productPriceInfo tag for ROAV Dixon
# Getting product attributes for ROAV Dixon
# getting data from https://eyewa.com/ae-en/30sundays-aces-000202-1206.html
# html response for 30Sundays ACES: 200
# found productPriceInfo tag for 30Sundays ACES
# Getting product attributes for 30Sundays ACES
# getting data from https://eyewa.com/ae-en/superdry-sprint-sds-sprint-106-blue.html
# html response for Superdry SPRINT: 200
# found productPriceInfo tag for Superdry SPRINT
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70104" data-product-id="70104" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="419" data-price-type="finalPrice" id="product-price-70104">
# <span class="price">AED 419</span> </span>
# </span>
# </div></div>
# Getting product attributes for Superdry SPRINT
# getting data from https://eyewa.com/ae-en/superdry-rockstep-sds-rockstep-127-black.html
# html response for Superdry ROCKSTEP: 200
# found productPriceInfo tag for Superdry ROCKSTEP
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70101" data-product-id="70101" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="419" data-price-type="finalPrice" id="product-price-70101">
# <span class="price">AED 419</span> </span>
# </span>
# </div></div>
# Getting product attributes for Superdry ROCKSTEP
# getting data from https://eyewa.com/ae-en/carrera-20345301058ir-silver.html
# html response for CARRERA - 1035/GS: 200
# found productPriceInfo tag for CARRERA - 1035/GS
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69934" data-product-id="69934" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="769" data-price-type="finalPrice" id="product-price-69934">
# <span class="price">AED 769</span> </span>
# </span>
# </div></div>
# Getting product attributes for CARRERA - 1035/GS
# getting data from https://eyewa.com/ae-en/carrera-200387807629o-black.html
# html response for CARRERA - 1007/S: 200
# found productPriceInfo tag for CARRERA - 1007/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69932" data-product-id="69932" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="629" data-price-type="finalPrice" id="product-price-69932">
# <span class="price">AED 629</span> </span>
# </span>
# </div></div>
# Getting product attributes for CARRERA - 1007/S
# getting data from https://eyewa.com/ae-en/polaroid-202917ipr51c3-tortoise.html
# html response for Polaroid - PLD 6111/S: 200
# found productPriceInfo tag for Polaroid - PLD 6111/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68671" data-product-id="68671" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="279" data-price-type="finalPrice" id="product-price-68671">
# <span class="price">AED 279</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - PLD 6111/S
# getting data from https://eyewa.com/ae-en/blackout-kate-petite-000201-1707.html
# html response for BlackOut KATE PETITE: 200
# found productPriceInfo tag for BlackOut KATE PETITE
# Getting product attributes for BlackOut KATE PETITE
# getting data from https://eyewa.com/ae-en/mr-wonderful-gold-mask-mw29045101-mw29045101.html
# html response for Mr. Wonderful Gold Mask - MW29045101: 200
# found productPriceInfo tag for Mr. Wonderful Gold Mask - MW29045101
# Getting product attributes for Mr. Wonderful Gold Mask - MW29045101
# getting data from https://eyewa.com/ae-en/roav-balto-1003-11-14.html
# html response for ROAV Balto: 200
# found productPriceInfo tag for ROAV Balto
# Getting product attributes for ROAV Balto
# getting data from https://eyewa.com/ae-en/blackout-amira-000211-2702.html
# html response for BlackOut AMIRA: 200
# found productPriceInfo tag for BlackOut AMIRA
# Getting product attributes for BlackOut AMIRA
# getting data from https://eyewa.com/ae-en/polaroid-201186b3v42mf-purple.html
# html response for Polaroid Junior - PLD 8019/S/SM - Age 3-8 Years: 200
# found productPriceInfo tag for Polaroid Junior - PLD 8019/S/SM - Age 3-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68698" data-product-id="68698" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="169" data-price-type="finalPrice" id="product-price-68698">
# <span class="price">AED 169</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid Junior - PLD 8019/S/SM - Age 3-8 Years
# getting data from https://eyewa.com/ae-en/polaroid-203431j5g57uc-gold.html
# html response for Polaroid - PLD 2106/G/S: 200
# found productPriceInfo tag for Polaroid - PLD 2106/G/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68620" data-product-id="68620" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-68620">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - PLD 2106/G/S
# getting data from https://eyewa.com/ae-en/30sundays-thats-fab-000131-1306.html
# html response for 30Sundays THAT'S FAB: 200
# found productPriceInfo tag for 30Sundays THAT'S FAB
# Getting product attributes for 30Sundays THAT'S FAB
# getting data from https://eyewa.com/ae-en/30sundays-nomad-000215-1306.html
# html response for 30Sundays NOMAD: 200
# found productPriceInfo tag for 30Sundays NOMAD
# Getting product attributes for 30Sundays NOMAD
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-203398kj16070-black.html
# html response for TOMMY HILFIGER - TH 1788/F/S: 200
# found productPriceInfo tag for TOMMY HILFIGER - TH 1788/F/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69996" data-product-id="69996" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="669" data-price-type="finalPrice" id="product-price-69996">
# <span class="price">AED 669</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER - TH 1788/F/S
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-20087808a56ir-black.html
# html response for TOMMY HILFIGER - TH 1556/S: 200
# found productPriceInfo tag for TOMMY HILFIGER - TH 1556/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69978" data-product-id="69978" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="509" data-price-type="finalPrice" id="product-price-69978">
# <span class="price">AED 509</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER - TH 1556/S
# getting data from https://eyewa.com/ae-en/marc-jacobs-203826pef53qt-gold.html
# html response for MARC JACOBS - MARC 532/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 532/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69972" data-product-id="69972" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="879" data-price-type="finalPrice" id="product-price-69972">
# <span class="price">AED 879</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 532/S
# getting data from https://eyewa.com/ae-en/polaroid-20338908653uc-tortoise.html
# html response for Polaroid - PLD 2095/S: 200
# found productPriceInfo tag for Polaroid - PLD 2095/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-68606" data-product-id="68606" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="249" data-price-type="finalPrice" id="product-price-68606">
# <span class="price">AED 249</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - PLD 2095/S
# getting data from https://eyewa.com/ae-en/blackout-xoxo-000205-2709.html
# html response for BlackOut XOXO: 200
# found productPriceInfo tag for BlackOut XOXO
# Getting product attributes for BlackOut XOXO
# getting data from https://eyewa.com/ae-en/mr-wonderful-gold-round-mw29055101-mw29055101.html
# html response for Mr. Wonderful Gold Round - MW29055101: 200
# found productPriceInfo tag for Mr. Wonderful Gold Round - MW29055101
# Getting product attributes for Mr. Wonderful Gold Round - MW29055101
# getting data from https://eyewa.com/ae-en/mr-wonderful-blue-round-mw29046147-mw29046147.html
# html response for Mr. Wonderful Blue Round - MW29046147: 200
# found productPriceInfo tag for Mr. Wonderful Blue Round - MW29046147
# Getting product attributes for Mr. Wonderful Blue Round - MW29046147
# getting data from https://eyewa.com/ae-en/30sundays-breeze-in-000132-1306.html
# html response for 30Sundays BREEZE IN: 200
# found productPriceInfo tag for 30Sundays BREEZE IN
# Getting product attributes for 30Sundays BREEZE IN
# getting data from https://eyewa.com/ae-en/30sundays-coast-along-000125-1306.html
# html response for 30Sundays COAST ALONG: 200
# found productPriceInfo tag for 30Sundays COAST ALONG
# Getting product attributes for 30Sundays COAST ALONG
# getting data from https://eyewa.com/ae-en/babamio nola kids ages - 4-8 years-000240-0207-blue.html
# html response for Babamio NOLA Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio NOLA Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70207" data-product-id="70207" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70207">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio NOLA Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio willow kids ages - 4-8 years-000239-0107-black.html
# html response for Babamio WILLOW Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio WILLOW Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70204" data-product-id="70204" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70204">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio WILLOW Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio evie kids ages - 4-8 years-000238-0907-pink.html
# html response for Babamio EVIE Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio EVIE Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70201" data-product-id="70201" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70201">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio EVIE Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio juniper kids ages - 4-8 years-000237-0207-blue.html
# html response for Babamio JUNIPER Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio JUNIPER Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70199" data-product-id="70199" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70199">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio JUNIPER Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio alder kids ages - 4-8 years-000236-0907-pink.html
# html response for Babamio ALDER Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio ALDER Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70195" data-product-id="70195" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70195">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio ALDER Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio sydney kids ages - 4-8 years-000234-0107-black.html
# html response for Babamio SYDNEY Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio SYDNEY Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70187" data-product-id="70187" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70187">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio SYDNEY Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio brynn kids ages - 4-8 years-000233-1007-purple.html
# html response for Babamio BRYNN Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio BRYNN Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70186" data-product-id="70186" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70186">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio BRYNN Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio rowan kids ages - 4-8 years-000232-0107-black.html
# html response for Babamio ROWAN Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio ROWAN Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70182" data-product-id="70182" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70182">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio ROWAN Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio jared kids ages - 4-8 years-000231-0107-black.html
# html response for Babamio JARED Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio JARED Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70179" data-product-id="70179" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70179">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio JARED Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio tatum kids ages - 4-8 years-000230-0107-black.html
# html response for Babamio TATUM Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio TATUM Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70175" data-product-id="70175" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70175">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio TATUM Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/babamio berkley kids ages - 4-8 years-000229-0107-black.html
# html response for Babamio BERKLEY Kids Ages - 4-8 Years: 200
# found productPriceInfo tag for Babamio BERKLEY Kids Ages - 4-8 Years
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70172" data-product-id="70172" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="159" data-price-type="finalPrice" id="product-price-70172">
# <span class="price">AED 159</span> </span>
# </span>
# </div></div>
# Getting product attributes for Babamio BERKLEY Kids Ages - 4-8 Years
# getting data from https://eyewa.com/ae-en/polaroid-202249pjp555x-blue.html
# html response for Polaroid - Junior PLD 8034/S: 200
# found productPriceInfo tag for Polaroid - Junior PLD 8034/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70044" data-product-id="70044" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="199" data-price-type="finalPrice" id="product-price-70044">
# <span class="price">AED 199</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - Junior PLD 8034/S
# getting data from https://eyewa.com/ae-en/polaroid-257582t2048y2-blue.html
# html response for Polaroid - Junior PLD 8001/S: 200
# found productPriceInfo tag for Polaroid - Junior PLD 8001/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70024" data-product-id="70024" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="299" data-price-type="finalPrice" id="product-price-70024">
# <span class="price">AED 299</span> </span>
# </span>
# </div></div>
# Getting product attributes for Polaroid - Junior PLD 8001/S
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-jeans-203966c9a52ku-red.html
# html response for TOMMY HILFIGER Jeans - TJ 0043/S: 200
# found productPriceInfo tag for TOMMY HILFIGER Jeans - TJ 0043/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70018" data-product-id="70018" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="509" data-price-type="finalPrice" id="product-price-70018">
# <span class="price">AED 509</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER Jeans - TJ 0043/S
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-jeans-2038397zj51ir-black.html
# html response for TOMMY HILFIGER Jeans - TJ 0040/S: 200
# found productPriceInfo tag for TOMMY HILFIGER Jeans - TJ 0040/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-70014" data-product-id="70014" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="509" data-price-type="finalPrice" id="product-price-70014">
# <span class="price">AED 509</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER Jeans - TJ 0040/S
# getting data from https://eyewa.com/ae-en/tommy-hilfiger-20332780751ir-black.html
# html response for TOMMY HILFIGER - TH 1764/S: 200
# found productPriceInfo tag for TOMMY HILFIGER - TH 1764/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69993" data-product-id="69993" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="669" data-price-type="finalPrice" id="product-price-69993">
# <span class="price">AED 669</span> </span>
# </span>
# </div></div>
# Getting product attributes for TOMMY HILFIGER - TH 1764/S
# getting data from https://eyewa.com/ae-en/marc-jacobs-203822807589o-black.html
# html response for MARC JACOBS - MARC 528/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 528/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69971" data-product-id="69971" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="559" data-price-type="finalPrice" id="product-price-69971">
# <span class="price">AED 559</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 528/S
# getting data from https://eyewa.com/ae-en/marc-jacobs-203830rhl62ir-gold.html
# html response for MARC JACOBS - MARC 522/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 522/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69965" data-product-id="69965" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="649" data-price-type="finalPrice" id="product-price-69965">
# <span class="price">AED 649</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 522/S
# getting data from https://eyewa.com/ae-en/marc-jacobs-202860j5g579o-gold.html
# html response for MARC JACOBS - MARC 456/S: 200
# found productPriceInfo tag for MARC JACOBS - MARC 456/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69959" data-product-id="69959" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="789" data-price-type="finalPrice" id="product-price-69959">
# <span class="price">AED 789</span> </span>
# </span>
# </div></div>
# Getting product attributes for MARC JACOBS - MARC 456/S
# getting data from https://eyewa.com/ae-en/carrera-20381700364m9-black.html
# html response for CARRERA - HOT65: 200
# found productPriceInfo tag for CARRERA - HOT65
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69945" data-product-id="69945" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="799" data-price-type="finalPrice" id="product-price-69945">
# <span class="price">AED 799</span> </span>
# </span>
# </div></div>
# Getting product attributes for CARRERA - HOT65
# getting data from https://eyewa.com/ae-en/carrera-20271600355uc-black.html
# html response for CARRERA - 231/S: 200
# found productPriceInfo tag for CARRERA - 231/S
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69939" data-product-id="69939" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="769" data-price-type="finalPrice" id="product-price-69939">
# <span class="price">AED 769</span> </span>
# </span>
# </div></div>
# Getting product attributes for CARRERA - 231/S
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29069512-black.html
# html response for Mr. Wonderful Black Round - MW29069512: 200
# found productPriceInfo tag for Mr. Wonderful Black Round - MW29069512
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69931" data-product-id="69931" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69931">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Black Round - MW29069512
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29067595-tortoise.html
# html response for Mr. Wonderful Tortoise Round - MW29067595: 200
# found productPriceInfo tag for Mr. Wonderful Tortoise Round - MW29067595
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69929" data-product-id="69929" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69929">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Tortoise Round - MW29067595
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29067515-gray.html
# html response for Mr. Wonderful Gray Round - MW29067515: 200
# found productPriceInfo tag for Mr. Wonderful Gray Round - MW29067515
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69928" data-product-id="69928" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69928">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Gray Round - MW29067515
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29065545-blue.html
# html response for Mr. Wonderful Blue Round - MW29065545: 200
# found productPriceInfo tag for Mr. Wonderful Blue Round - MW29065545
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69927" data-product-id="69927" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69927">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Blue Round - MW29065545
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29063595-tortoise.html
# html response for Mr. Wonderful Tortoise Square - MW29063595: 200
# found productPriceInfo tag for Mr. Wonderful Tortoise Square - MW29063595
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69924" data-product-id="69924" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69924">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Tortoise Square - MW29063595
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29063516-gray.html
# html response for Mr. Wonderful Gray Square - MW29063516: 200
# found productPriceInfo tag for Mr. Wonderful Gray Square - MW29063516
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69921" data-product-id="69921" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="219" data-price-type="finalPrice" id="product-price-69921">
# <span class="price">AED 219</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Gray Square - MW29063516
# getting data from https://eyewa.com/ae-en/mr-wonderful-mw29022512-black.html
# html response for Mr. Wonderful Black Cat Eye - MW29022512: 200
# found productPriceInfo tag for Mr. Wonderful Black Cat Eye - MW29022512
# 'NoneType' object is not subscriptable
# ...
# html response for Spectus SUZETTE: 200
# found productPriceInfo tag for Spectus SUZETTE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69160" data-product-id="69160" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69160">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus SUZETTE
# getting data from https://eyewa.com/ae-en/spectus-estelle-000176-0109.html
# html response for Spectus ESTELLE: 200
# found productPriceInfo tag for Spectus ESTELLE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69259" data-product-id="69259" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69259">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus ESTELLE
# getting data from https://eyewa.com/ae-en/spectus-theodore-tf1539-56-004.html
# html response for Spectus THEODORE: 200
# found productPriceInfo tag for Spectus THEODORE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69222" data-product-id="69222" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69222">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus THEODORE
# getting data from https://eyewa.com/ae-en/artlife-leto-al68295201.html
# html response for Artlife LETO: 200
# found productPriceInfo tag for Artlife LETO
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-58395" data-product-id="58395" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-58395">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Artlife LETO
# getting data from https://eyewa.com/ae-en/artlife-gordon-al68282101.html
# html response for Artlife GORDON: 200
# found productPriceInfo tag for Artlife GORDON
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-58394" data-product-id="58394" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-58394">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Artlife GORDON
# getting data from https://eyewa.com/ae-en/spectus-victoria-tf1507-53-004.html
# html response for Spectus VICTORIA: 200
# found productPriceInfo tag for Spectus VICTORIA
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-58301" data-product-id="58301" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-58301">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Spectus VICTORIA
# getting data from https://eyewa.com/ae-en/spectus-martin-tf1438-54-003.html
# html response for Spectus Martin: 200
# found productPriceInfo tag for Spectus Martin
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-58296" data-product-id="58296" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-58296">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Spectus Martin
# getting data from https://eyewa.com/ae-en/mr-wonderful-pink-cat-eye-mw69087567.html
# html response for Mr. Wonderful Pink Cat Eye: 200
# found productPriceInfo tag for Mr. Wonderful Pink Cat Eye
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-57713" data-product-id="57713" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-57713">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Pink Cat Eye
# getting data from https://eyewa.com/ae-en/mr-wonderful-tortoise-cat-eye-mw69032595.html
# html response for Mr. Wonderful Tortoise Cat Eye: 200
# found productPriceInfo tag for Mr. Wonderful Tortoise Cat Eye
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-55633" data-product-id="55633" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-55633">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Tortoise Cat Eye
# getting data from https://eyewa.com/ae-en/mr-wonderful-gold-aviator-mw69116101.html
# html response for Mr. Wonderful Gold Aviator: 200
# found productPriceInfo tag for Mr. Wonderful Gold Aviator
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-57704" data-product-id="57704" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-57704">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Gold Aviator
# getting data from https://eyewa.com/ae-en/puma-pu0304o-004-gray.html
# html response for Puma PU0304O: 200
# found productPriceInfo tag for Puma PU0304O
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69257" data-product-id="69257" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="469" data-price-type="finalPrice" id="product-price-69257">
# <span class="price">AED 469</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Puma PU0304O
# getting data from https://eyewa.com/ae-en/mcq-mq0245op.html
# html response for McQ MQ0245OP: 502
# <span class="cf-error-type">Error</span>
# retrying a new connection to https://eyewa.com/ae-en/mcq-mq0245op.html
# found productPriceInfo tag for McQ MQ0245OP
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-60260" data-product-id="60260" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="769" data-price-type="finalPrice" id="product-price-60260">
# <span class="price">AED 769</span> </span>
# </span>
# </div></div>
# Getting product attributes for McQ MQ0245OP
# getting data from https://eyewa.com/ae-en/puma-pu0261o.html
# html response for PUMA PU0261O: 200
# found productPriceInfo tag for PUMA PU0261O
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-60229" data-product-id="60229" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="449" data-price-type="finalPrice" id="product-price-60229">
# <span class="price">AED 449</span> </span>
# </span>
# </div></div>
# Getting product attributes for PUMA PU0261O
# getting data from https://eyewa.com/ae-en/roav-ace-6004-14.html
# html response for ROAV Ace: 200
# found productPriceInfo tag for ROAV Ace
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69118" data-product-id="69118" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="699" data-price-type="finalPrice" id="product-price-69118">
# <span class="price">AED 699</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for ROAV Ace
# getting data from https://eyewa.com/ae-en/spectus-max-309-0118.html
# html response for Spectus MAX - Titanium: 200
# found productPriceInfo tag for Spectus MAX - Titanium
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69198" data-product-id="69198" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="549" data-price-type="finalPrice" id="product-price-69198">
# <span class="price">AED 549</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus MAX - Titanium
# getting data from https://eyewa.com/ae-en/spectus-natalie-eyeglasses-000121-0100.html
# html response for Spectus NATALIE: 200
# found productPriceInfo tag for Spectus NATALIE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-59412" data-product-id="59412" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-59412">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Spectus NATALIE
# getting data from https://eyewa.com/ae-en/spectus-lucas-tortoise-02.html
# html response for Spectus LUCAS: 200
# found productPriceInfo tag for Spectus LUCAS
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69205" data-product-id="69205" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69205">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus LUCAS
# getting data from https://eyewa.com/ae-en/spectus-christoffer-tf1351-49-003.html
# html response for Spectus CHRISTOFFER: 200
# found productPriceInfo tag for Spectus CHRISTOFFER
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69212" data-product-id="69212" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69212">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus CHRISTOFFER
# getting data from https://eyewa.com/ae-en/mr-wonderful-gold-round-mw69115221.html
# html response for Mr. Wonderful Gold Round: 200
# found productPriceInfo tag for Mr. Wonderful Gold Round
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-57705" data-product-id="57705" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-57705">
# <span class="price">AED 399</span> </span>
# </span>
# </div></div>
# Getting product attributes for Mr. Wonderful Gold Round
# getting data from https://eyewa.com/ae-en/spectus-nora-eye-glasses-000137-1324.html
# html response for Spectus NORA: 200
# found productPriceInfo tag for Spectus NORA
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69140" data-product-id="69140" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69140">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus NORA
# getting data from https://eyewa.com/ae-en/spectus-joe-brown-01.html
# html response for Spectus JOE: 200
# found productPriceInfo tag for Spectus JOE
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-69200" data-product-id="69200" data-role="priceBox">
# <span class="normal-price">
# <span class="price-container price-final_price tax weee">
# <span class="price-label">As low as</span>
# <span class="price-wrapper" data-price-amount="399" data-price-type="finalPrice" id="product-price-69200">
# <span class="price">AED 399</span> </span>
# </span>
# </span>
# </div></div>
# Getting product attributes for Spectus JOE
# getting data from https://eyewa.com/ae-en/mcq-mq0275o-002-tortoise.html
# html response for McQ MQ0275O: 200
# found productPriceInfo tag for McQ MQ0275O
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-63715" data-product-id="63715" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="659" data-price-type="finalPrice" id="product-price-63715">
# <span class="price">AED 659</span> </span>
# </span>
# </div></div>
# Getting product attributes for McQ MQ0275O
# getting data from https://eyewa.com/ae-en/mcq-mq0289o-002-tortoise.html
# html response for McQ MQ0289O: 200
# found productPriceInfo tag for McQ MQ0289O
# 'NoneType' object is not subscriptable
# <div class="product-info-price" id="productPriceInfo"><div class="price-box price-final_price" data-price-box="product-id-63716" data-product-id="63716" data-role="priceBox">
# <span class="price-container price-final_price tax weee">
# <span class="price-wrapper" data-price-amount="799" data-price-type="finalPrice" id="product-price-63716">
# <span class="price">AED 799</span> </span>
# </span>
# </div></div>
# Getting product attributes for McQ MQ0289O
# getting data from https://eyewa.com/ae-en/puma-pu0307o-003-brown.html

# %%
engine = create_engine('sqlite:///../data/eyewa.db', echo=False)

# %%
df= pd.DataFrame.from_dict(all_products_dict2,orient='index')
df['date_created'] = datetime.now()
df['date_created'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0908f737dec5> in <module>
# ----> 1 df= pd.DataFrame.from_dict(all_products_dict2,orient='index')
#       2 df['date_created'] = datetime.now()
#       3 df['date_created'].head()
#
# NameError: name 'all_products_dict2' is not defined

# %%
df.to_sql('eyewa_catalogue_archive', con=engine, if_exists='append')

# %%
def catalogue_sections_getter():
    #bs4 & requests
    webpage = requests.get('https://eyewa.com/ae-en/', 'html.parser')
    soup = BeautifulSoup(webpage.content)

    #fina\d the header
    header_menu = soup.find(attrs={"id": "mainMenu"}).find_all('li', attrs={"class":["mega-menu-item mega-menu-fullwidth menu-3columns level0 static-menu level0 dropdown","mega-menu-item mega-menu-fullwidth menu-2columns level0 static-menu level0 dropdown"]} )

    #input the section into a dict
    sections_dict = {}
    for section in header_menu:
        #print(section.a.span.string, section.a['href'])
        sections_dict[section.a.span.string] = section.a['href']

    return sections_dict

def product_list_getter(sections_dict):
    all_products_dict = {}
    for x,y in sections_dict.items():
        next_link=y
        while next_link != True:
            product_details_getter(all_products_dict, next_link)
            next_link = next_page_finder(next_link)
    
    return all_products_dict


def product_details_getter(all_products_dict, link):
    print(f'getting data from {link}')
    webpage = requests.get(link, 'html.parser')
    soup = BeautifulSoup(webpage.content)
    try:
        product_list =  soup.find(attrs={'class':"products list items product-items row row-col-lg-3"})
        for i in product_list.find_all('li'): 
            product_top =i.find(attrs={'class':'product-top'})
            product_url = product_top.a['href']
            product_top = product_top.a.find('img')
            product_name = product_top['alt']
            product_picture = product_top['src']
            
            all_products_dict[product_name]={}
            all_products_dict[product_name]['product_url']=product_url
            all_products_dict[product_name]['picture_url']=product_picture
    except Exception as e:
        print(e)

def product_detail_getter_2(all_products_dict):
    
    for key in all_products_dict.keys():
        current_link = all_products_dict[key]['product_url']
        links_not_working = {}

        print(f'getting data from {current_link}')
        html = requests.get(current_link)
        
        if html.status_code == 404:
            links_not_working[key] = current_link
            print(f'html response for {key}: {html.status_code}')
            continue
        else:
            print(f'html response for {key}: {html.status_code}')
        
        
        soup = BeautifulSoup(html.content)

        retries=0
        if  soup.find(attrs={'class':'cf-error-type'}) != None :
            if retries < 5:
                print(soup.find(attrs={'class':'cf-error-type'}))
                print(f'retrying a new connection to {current_link}')
                html = requests.get(current_link)
                soup = BeautifulSoup(html.content)
                retries += 1
        
            else:
                print(f"Current link didn't work: {current_link}")
                links_not_working[key] = current_link
                continue

        
        try:
            id = soup.find(attrs={'class':'price-box price-final_price'})['data-product-id']
            all_products_dict[key]['product_id'] = id
        except:
            print(f"couldnt find product id for {key}")
            print(soup.find(attrs={'class':'price-box price-final_price'}))

        retries = 0    
        if soup.find(attrs={'id':'productPriceInfo'}) is None:
            if retries < 5:
                print(f'retrying a new connection to {current_link}')
                html = requests.get(current_link)
                soup = BeautifulSoup(html.content)
                retries += 1
            else:
                continue
        else:
            price =  soup.find(attrs={'id':'productPriceInfo'})
            print(f'found productPriceInfo tag for {key}')
            try:
                oldPrice = price.find(attrs={'class':'price-wrapper','data-price-type':'oldPrice'})['data-price-amount']
                currentPrice = price.find(attrs={'class':'price-wrapper','data-price-type':'finalPrice'})['data-price-amount']
                all_products_dict[key]['discounted'] = 'yes'
                all_products_dict[key]['discountedPrice'] = currentPrice
                all_products_dict[key]['actualPrice'] = oldPrice
                

            except Exception as e:
                print(e)
                print(price)
                currentPrice = price.find(attrs={'class':'price-wrapper','data-price-type':'finalPrice'})['data-price-amount']   
                all_products_dict[key]['discounted'] = 'no'
                all_products_dict[key]['actualPrice'] = currentPrice



        table = soup.find(attrs={'class':'data table additional-attributes'}).find('tbody')
        rows = table.find_all('td')
        print(f'Getting product attributes for {key}')
        for row in range(len(rows)):        
            all_products_dict[key][rows[row]['data-th']] = rows[row].string
    

    return all_products_dict

def next_page_finder(current_link):
    try:
        next_link = requests.get(current_link, 'html.parser')
        next_link = BeautifulSoup(next_link.content)
        next_link = next_link.find('li',attrs={'class':'item pages-item-next'}).a['href']
        return next_link

    except Exception as e:
        print('End of the ride for this category')
        return True

def product_dataframe(all_products_dict):
    df = pd.DataFrame.from_dict(all_products_dict,orient='index')
    print(df.head())
    return df
